# %% [markdown]
# # New York Fed Replication

# %%
# Setting up 

import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

sample = "~//projects//equifaxmacro_proj//EquiFax3//2_10_Percent_Sample_Construction//output//sample//"
output_3 = "~//projects//equifaxmacro_proj//EquiFax3//3_Balance_In_And_Out_Construction//output//"

# %%
# we're only going to pull every third month, since it's quarterly 

def monyr(monnum):

    mon = (monnum + 5) % 12 + 1

    if mon < 10: 
        MONNUM = "0" + str(mon)
    else: 
        MONNUM = str(mon)

    YRNUM = int(((monnum - mon)/12) + 2006)

    DATE = str(YRNUM) + MONNUM
    
    return DATE;

quartercols = [monyr(3*quarternum) for quarternum in range(1, 66)]

# %% [markdown]
# ## Ones that just look at balances and accounts

# %%
alltl_str = output_3 + "1_balance_in_and_out.parquet"
alltl = pd.read_parquet(alltl_str, columns = quartercols).reset_index()

# %%
non_other_pc_types = [
            'FM', # first mortgage
            'HR', # home equity revolving 
            'AB2', # auto bank loan
            'AF2', # auto finance loan
            'BC', # bank card 
            'RT', # retail 
            'SL1', # student loan deferred
            'SL2', # student loan non-deferred  
            ]

# %%
# calculate totals for the classic types first
non_other = alltl[alltl.product_category.isin(non_other_pc_types)]
other = alltl[~alltl.product_category.isin(non_other_pc_types)]

# %%
# now, recode the equifax product categories for the non-others 

# mortgage 
non_other.loc[non_other['product_category'] == 'FM', 'product_category'] = 'first_mortgage'

# home equity revolving 
non_other.loc[non_other['product_category'] == 'HR', 'product_category'] = 'he_revolving'

# auto loan 
non_other.loc[non_other['product_category'].isin(['AB2', 'AF2']), 'product_category'] = 'auto'

# credit card
non_other.loc[non_other['product_category'].isin(['BC', 'RT']), 'product_category'] = 'credit_card'

# student loan
non_other.loc[non_other['product_category'].isin(['SL1', 'SL2']), 'product_category'] = 'student_loan'
# Out:
# /home/afan/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
sum = non_other.drop(['consumer_id', 'trade_id'], axis = 1).head(100000).groupby('product_category').sum()

# %%
# now let's group the "other" group for each month

sum_other = other.iloc[:, 3:].head(1000).sum()
sum_other = pd.DataFrame(sum_other).T

# %%
sum_other.index = ['other']

# %%
a = pd.concat([sum, sum_other], axis = 0).T
a.columns = a.columns + "_bal"
a
# Out:
#           auto_bal  credit_card_bal  first_mortgage_bal  he_revolving_bal  \
# 200509  19598671.0       16685436.0         210621220.0        16106602.0
# 200512  19731469.0       15643891.0         214778780.0        17384171.0
# 200603  20043822.0       15325567.0         222715266.0        17062215.0
# 200606  20251237.0       15647998.0         230380957.0        17607817.0
# 200609  20487943.0       15629123.0         236577998.0        17518739.0
# 200612  20554424.0       16004968.0         236795132.0        17987982.0
# 200703  20224278.0       15277200.0         242410928.0        17437228.0
# 200706  19962624.0       15920295.0         251443726.0        19183336.0
# 200709  20210152.0       16300289.0         254391176.0        20520435.0
# 200712  20613620.0       16933425.0         254411069.0        21267362.0
# 200803  20497325.0       16952564.0         260731676.0        22316047.0
# 200806  20442073.0       17408267.0         263741092.0        22479876.0
# 200809  20136516.0       17819310.0         266274564.0        23049767.0
# 20     14157373   2005-07-26   95062.0                 99.0
# 31     17458230   2005-07-26   29645.0                  0.0
#
#     age_oldest_account  age_oldest_mortgage_account  age_newest_account  \
# 5                154.0                         22.0                 2.0
# 6                139.0                         82.0                 9.0
# 13               226.0                       9998.0                15.0
# 20               166.0                         90.0                 6.0
# 31               366.0                        366.0                 6.0
#
#     number_of_accounts  number_accounts_opened_within_12_months  \
# 5                 22.0                                      3.0
# 6                 25.0                                      2.0
# 13                12.0                                      0.0
# 20                19.0                                      1.0
# 31                36.0                                      1.0
#
#     number_accounts_always_satisfactory  number_accounts_major_derogatory  \
# 5                                  22.0                               0.0
# 6                                   5.0                               3.0
# 13                                 11.0                               0.0
# 20                                 18.0                               1.0
# 31                                 34.0                               0.0
#
#     number_revolving_accts_greater_than_or_equal_to_50_percent_utilization  \
# 5                                                                      0.0
# 6                                                                      8.0
# 13                                                                     1.0
# 20                                                                     0.0
# 31                                                                     0.0
#
#     bankcard_accts_over_75_percent_utilization  number_accounts_past_due  \
# 5                                          0.0                       0.0
# 6                                          2.0                      13.0
# 13                                         0.0                       0.0
# 20                                         0.0                       0.0
# 31                                         0.0                       0.0
#
#     total_past_due_amount  bankruptcy_flag  foreclosure_flag  \
# 5                     0.0              0.0               0.0
# 6                 10369.0              0.0               0.0
# 13                    0.0              0.0               0.0
# 20                    0.0              0.0               0.0
# 31                    0.0              0.0               0.0
#
#     number_3rd_party_collection_accts  total_amount_3rd_party_collections  \
# 5                                 0.0                           9999998.0
# 6                                 0.0                           9999998.0
# 13                                1.0                               651.0
# 20                                0.0                           9999998.0
# 31                                0.0                           9999998.0
#
#     number_open_bankcard_accounts  number_open_mortgage_accounts  \
# 5                             4.0                            1.0
# 6                             2.0                            1.0
# 13                            1.0                           98.0
# 20                            2.0                            1.0
# 31                            9.0                            1.0
#
#     vantage_score_3 state   trade_id  origination_date_open  \
# 5               779    NJ  191208105               200505.0
# 6               420    GA  191208327               200311.0
# 13              762    FL  191211683               199108.0
# 20              789    CA  192492211               199607.0
# 31              783    SC  192496127               198805.0
#
#    origination_portfolio_type origination_product_category  \
# 5                           R                           RT
# 6                           R                           RT
# 13                          R                           RT
# 20                          R                           RT
# 31                          R                           BC
#
#     origination_vantage_score3 product_category  small_business_owner_flag  \
# 5                        779.0               RT                        NaN
# 6                        420.0               RT                        NaN
# 13                       762.0               RT                        NaN
# 20                       789.0               RT                        NaN
# 31                       783.0               BC                        NaN
#
#     pim_score  consumer_age  mortgage_indicator  deceased_consumer  terms  \
# 5          51             6                   1                  0    NaN
# 6          35             3                   1                  0    NaN
# 13         41             3                   0                  0    NaN
# 20         50             3                   1                  0    NaN
# 31         48             5                   1                  0    NaN
#
#     status_category  balance  high_credit  monthly_payment portfolio_type  \
# 5                 1        0         6000                0              R
# 6                 1      189          254               10              R
# 13                1     3523         7500              360              R
# 20                8        0          230                0              R
# 31                1        0         5800                0              R
#
#     transferred_sold_flag date_reported  narrcode_1  narrcode_2  narrcode_3  \
# 5                       1    2005-06-01         233           0           0
# 6                       0    2005-07-01         233           0           0
# 13                      0    2005-07-01         233           0           0
# 20                      1    2005-07-01         244          65           0
# 31                      0    2005-07-01         233           0           0
#
#     narrcode_4 ecoa rate_status  scheduled_payment_amount  \
# 5            0    I           1                       NaN
# 6            0    I           1                      10.0
# 13           0    I           1                     360.0
# 20           0    I           9                       NaN
# 31           0    J           1                       NaN
#
#    date_of_last_activity date_of_last_payment  actual_payment_amount  \
# 5                   None                 None                    NaN
# 6             2005-07-01           2005-06-01                   50.0
# 13            2005-07-01           2005-06-01                    NaN
# 20            2001-12-01           2002-10-01                    NaN
# 31            2000-12-01           2000-12-01                    NaN
#
#    payment_frequency account_type activity_designator  \
# 5               None           07                None
# 6                  M           07                None
# 13              None           07                None
# 20              None           07                   B
# 31              None           18                None
#
#     origination_vantage_score4  origination_Bankruptcy_Navigator_Index  \
# 5                        775.0                                   360.0
# 6                        456.0                                     1.0
# 13                       710.0                                   388.0
# 20                       765.0                                   309.0
# 31                       791.0                                   450.0
#
#     origination_Consumer_Income_Score  vantage_score_4  \
# 5                                37.0              775
# 6                                31.0              456
# 13                               59.0              710
# 20                               41.0              765
# 31                               47.0              791
#
#     bankruptcy_Navigator_Index  consumer_Income_Score  \
# 5                          360                     37
# 6                            1                     31
# 13                         388                     59
# 20                         309                     41
# 31                         450                     47
#
#     revolver_Transactor_Behavior_Last_6_Months  \
# 5                                          9.0
# 6                                          9.0
# 13                                         9.0
# 20                                         9.0
# 31                                         9.0
#
#     revolver_Transactor_Behavior_Last_12_Months  \
# 5                                           9.0
# 6                                           9.0
# 13                                          9.0
# 20                                          9.0
# 31                                          9.0
#
#     revolver_Transactor_Behavior_Last_24_Months  \
# 5                                           9.0
# 6                                           9.0
# 13                                          9.0
# 20                                          9.0
# 31                                          9.0
#
#     percent_Actual_Payment_to_Scheduled_Payment_Auto_Last_6_Months  \
# 5                                                           9999.0
# 6                                                           9999.0
# 13                                                          9999.0
# 20                                                          9999.0
# 31                                                          9999.0
#
#     percent_Actual_Payment_to_Scheduled_Payment_Auto_Last_12_Months  \
# 5                                                            9999.0
# 6                                                            9999.0
# 13                                                           9999.0
# 20                                                           9999.0
# 31                                                           9999.0
#
#     percent_Actual_Payment_to_Scheduled_Payment_Auto_Last_24_Months  \
# 5                                                            9999.0
# 6                                                            9999.0
# 13                                                           9999.0
# 20                                                           9999.0
# 31                                                           9999.0
#
#     percent_Actual_Payment_to_Scheduled_Payment_Mortage_Last_6_Months  \
# 5                                                              9999.0
# 6                                                              9999.0
# 13                                                             9999.0
# 20                                                             9999.0
# 31                                                             9999.0
#
#     percent_Actual_Payment_to_Scheduled_Payment_Mortage_Last_12_Months  \
# 5                                                               9999.0
# 6                                                               9999.0
# 13                                                              9999.0
# 20                                                              9999.0
# 31                                                              9999.0
#
#     percent_Actual_Payment_to_Scheduled_Payment_Mortage_Last_24_Months  \
# 5                                                               9999.0
# 6                                                               9999.0
# 13                                                              9999.0
# 20                                                              9999.0
# 31                                                              9999.0
#
#     mortgage_inquiries_last_1_month  \
# 5                                 0
# 6                                 0
# 13                                0
# 20                                0
# 31                                0
#
#     potential_Mortgage_inquiries_last_1_month origination_Industry_code  \
# 5                                           0                        DC
# 6                                           0                        CG
# 13                                          0                        DC
# 20                                          0                        DC
# 31                                          0                        BB
#
#    industry_code  consumer_age_archive  joint_Holders_In_Set  weight     m_y  \
# 5             DC                     6                     0       1  200507
# 6             CG                     3                     0       1  200507
# 13            DC                     3                     0       1  200507
# 20            DC                     3                     0       1  200507
# 31            BB                     5                     0       1  200507
#
#             csv_name    id_num
# 5   200507_2_ADS.csv  67247961
# 6   200507_2_ADS.csv  67247962
# 13  200507_2_ADS.csv  67247969
# 20  200507_2_ADS.csv  22923984
# 31  200507_2_ADS.csv  22923995

# %% [markdown]
# ## total number of new accounts and inquiries

# %%
# clean the exception values to zero 
mon1.loc[mon1['inquiries_12_months']>=92, 'inquiries_12_months'] = 0
mon1.loc[mon1['number_accounts_opened_within_12_months']>=92, 'number_accounts_opened_within_12_months'] = 0

# %%
acc_iq = mon1[['consumer_id', 'inquiries_12_months', 'number_accounts_opened_within_12_months']].drop_duplicates()

# %%
mon1.shape
# Out:
# (13903042, 80)

# %%
acc_iq.shape
# Out:
# (1975837, 3)

# %%
acc_iq_sum = acc_iq[['inquiries_12_months', 'number_accounts_opened_within_12_months']].sum()

# %%
acc_iq_vars = ['consumer_id', 'inquiries_12_months', 'number_accounts_opened_within_12_months']

acc_iq_sum
# Out:
# inquiries_12_months                        3530814.0
# number_accounts_opened_within_12_months    2397473.0
# dtype: float64

# %% [markdown]
# ## Credit score at origination: Mortgages and Auto loans

# %%
orig_cred = mon1[['transferred_sold_flag', 'origination_vantage_score3', 'product_category']]

# %%
orig_cred.columns = ['new_origination_flag', 'origination_vantage_score3', 'product_category']

# %%
 # find people with new mortgages and calculate percentiles 
mort = orig_cred[(orig_cred['product_category'] == "FM") & (orig_cred['new_origination_flag'] == 1)]
mp = mort['origination_vantage_score3'].describe(percentiles = [0.1, 0.25, 0.5]).iloc[4:7]

# find people with new auto loans and calculate percentils 
auto = orig_cred[(orig_cred['product_category'].isin(['AB2', 'AF2'])) & (orig_cred['new_origination_flag'] == 1)]
ap = auto['origination_vantage_score3'].describe(percentiles = [0.1, 0.25, 0.5]).iloc[4:7]

# create the values for the rows and make labels
row = pd.DataFrame(pd.concat([mp, ap]))
row.index = ['mort_10%', 'mort_25%', 'mort_50%', 'auto_10%', 'auto_25%', 'auto_50%']

# %%
orig_cred_cols = ['transferred_sold_flag', 'origination_vantage_score3', 'product_category']
row
# Out:
#           origination_vantage_score3
# mort_10%                       584.0
# mort_25%                       653.0
# mort_50%                       728.0
# auto_10%                       524.0
# auto_25%                       590.0
# auto_50%                       670.0

# %% [markdown]
# ## Derogatory debt

# %%
derog_vars = ['status_category', 'balance']

# %%
derog = mon1[derog_vars]

# %%
derog.balance.sum()
# Out:
# 142732607043

# %%
derog_stat = derog.groupby('status_category').sum()/derog.balance.sum()
derog_stat.index = ['Miscellaneous',
                    'Current',
                    '30 DPD',
                    '60 DPD',
                    '90 DPD',
                    '120 DPD or Collections',
                    'Foreclosure Started',
                    'Closed-Positive',
                    'Closed-Severe Derogatory',
                    'Closed-Bankruptcy']

# %%
derog_stat
# Out:
#                            balance
# Miscellaneous             0.012915
# Current                   0.950366
# 30 DPD                    0.013224
# 60 DPD                    0.004043
# 90 DPD                    0.001849
# 120 DPD or Collections    0.005138
# Foreclosure Started       0.002186
# Closed-Positive           0.000000
# Closed-Severe Derogatory  0.008120
# Closed-Bankruptcy         0.002159

# %%
mon2_str = sample + "201010_10perc.parquet"
mon2 = pd.read_parquet(mon2_str, columns = derog_vars)

# %%
mon2.groupby('status_category').sum()/mon2.balance.sum()
# Out:
#                   balance
# status_category
# 0                0.015047
# 1                0.883369
# 2                0.018594
# 3                0.009752
# 4                0.005928
# 5                0.031297
# 6                0.018895
# 7                0.000000
# 8                0.012682
# 9                0.004435

# %%
derog_type_vars = ['product_category', 'status_category', 'balance']

# %%
derog_type = mon1[derog_type_vars]

# %%
derog_type['sd'] = (derog_type.status_category >= 4) * 1
# Out:
# /tmp/ipykernel_214674/4285756938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   derog_type['sd'] = (derog_type.status_category >= 4) * 1

# %%
# now, recode the equifax product categories for the non-others 
def recode_nyfrb(non_other): 
    # mortgage 
    non_other.loc[non_other['product_category'] == 'FM', 'product_category'] = 'first_mortgage'

    # home equity revolving 
    non_other.loc[non_other['product_category'] == 'HR', 'product_category'] = 'he_revolving'

    # auto loan 
    non_other.loc[non_other['product_category'].isin(['AB2', 'AF2']), 'product_category'] = 'auto'

    # credit card
    non_other.loc[non_other['product_category'].isin(['BC', 'RT']), 'product_category'] = 'credit_card'

    # student loan
    non_other.loc[non_other['product_category'].isin(['SL1', 'SL2']), 'product_category'] = 'student_loan'
    
    non_other = non_other[non_other.product_category.isin(['first_mortgage', 'he_revolving', 'auto', 'credit_card', 'student_loan'])]
    
    return non_other;

# %%
derog_type = recode_nyfrb(derog_type)
# Out:
# /home/afan/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
derog_type.loc[derog_type.sd==1, ['product_category', 'balance']].groupby(['product_category']).sum()/derog_type[['product_category', 'balance']].groupby('product_category').sum()
# Out:
#                    balance
# product_category
# auto              0.022711
# credit_card       0.087769
# first_mortgage    0.009869
# he_revolving      0.002131
# student_loan      0.073219

# %% [markdown]
# ## Third party collections

# %%
tpc_vars = ['consumer_id', 'number_3rd_party_collection_accts','total_amount_3rd_party_collections']

tpc = mon1[tpc_vars]

# %%
tpc.
# Out:
#     consumer_id  number_3rd_party_collection_accts  \
# 5       7997902                                0.0
# 6       6373039                                0.0
# 13     15170225                                1.0
# 20     14157373                                0.0
# 31     17458230                                0.0
#
#     total_amount_3rd_party_collections
# 5                            9999998.0
# 6                            9999998.0
# 13                               651.0
# 20                           9999998.0
# 31                           9999998.0

# %%
# drop duplicates, recode variables, let's do this another day.
